# %% [markdown]
# # Daily Activities
# 1. W1:
# 	- D1: Virtual environments, Bash,
# 	- D2: sets, timedate, copy
# 	- D3: API - twitter API, HTTP requests
# 	- D4: Mini project I
# 	- D5: databases, SQL, conditional probability/bayes theorem, hypothesis testing, CLT
# 	- WE: Pandas, postgres, weather API
# 2. W2:
# 	- D1: Postgres SQL, Window Functions, SQL
# 	- D2: Pandas (merge, groupby, apply func, Pandas exercise 1-6
# 	- D3: JSON, XML, HTML, Data wrangling Challenge (Foursquare and Weather API)
# 	- D4: Mini project II
# 	- D5: Regex
# 	- WE: Dataviz intro reading
# 3. W3:
# 	- D1: Dataviz - MatPltLib, Seaborn, Plotly
# 		○ Stretch: tableau
# 	- D2: Matplotlib - stateless Approach, 3D. Maps in Python, interactive charts, Data Viz Challenge - soccer data
# 		○ Stretch: more tableau
# 	- D3: Intro to ML, Data prep, data exploration, outlier detection, null value replacement, value transformation, Feature Engineering (house data)
# 	- D4: Unsupervised Learning, Clustering, Centroid Models, Hierarchical models, density models
# 	- D5: Matrices, eigenthings, matrix decomp
# 	- WE: Calc, min and max of functions
# 4. W4:
# 	- D1: Dimensionality reduction - PCA, Variable Selection (again the House Data),
# 		○ STRETCH: Linear Discriminant Analysis (LDA) & MDS
# 	- D2: Miniproject #3 (clustering, PCA, radar charts)
# 	- D3: Intro to supervised learning, Generalization Error (loss and risk functions), Linear Regression, Classification, Polynomial regression
# 	- D4: Bias, Gradient Descent (challenge uses basketball data) (in day 3 folder), Regularization (ridge, lasso)
# 	- D5: presentation
# 	- WK: Classes, OOP
#
# 5. W5:
# 	- D1: Kfold cross validation, overfitting, class imbalance, sampling bias, Model Evaluation (Regression and Classification Metrics) (used house data again)
# D2: Odds, Logistic Regression (Iris data), GLM

# %% [markdown]
# ![image.png](attachment:d590dd1b-164e-4200-ad50-8e16090e1904.png)

# %% [markdown]
# ![image.png](attachment:2a5eb430-181e-45d4-b5b7-1b9be584bc50.png)
